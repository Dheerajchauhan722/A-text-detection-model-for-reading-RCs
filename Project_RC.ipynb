# %% [markdown]
# # A text detection model for reading RCs

# %% [markdown]
# # Dheeraj  Ph: 8708076289

# %%
import pytesseract
import pandas as pd
from PIL import Image,ImageEnhance
import os
pytesseract.pytesseract.tesseract_cmd=r"Tesseract-OCR\tesseract.exe"

# %% [markdown]
# # Making a list(name = filelist1) which holds the names of all images in RC folder

# %%
filelist1=os.listdir('images')
for i in range(len(filelist1)):
    print(i,filelist1[i])
# Out:
# 0 txt_mudit_b11_11597.jpg
# 1 txt_mudit_b11_11599.jpg
# 2 txt_mudit_b11_12.jpg
# 3 txt_mudit_b11_1328.jpg
# 4 txt_mudit_b11_1330.jpg
# 5 txt_mudit_b11_1332.jpg
# 6 txt_mudit_b11_1334.jpg
# 7 txt_mudit_b11_1337.jpg
# 8 txt_mudit_b11_1339.jpg
# 9 txt_mudit_b11_1343.jpg
# 10 txt_mudit_b11_1347.jpg
# 11 txt_mudit_b11_1354.jpg
# 12 txt_mudit_b11_1355.jpg
# 13 txt_mudit_b11_1361.jpg
# 14 txt_mudit_b11_1362.jpg
# 15 txt_mudit_b11_1363.jpg
# 16 txt_mudit_b11_1364.jpg
# 17 txt_mudit_b11_1365.jpg
# 18 txt_mudit_b11_1369.jpg
# 19 txt_mudit_b11_1524.jpg
# 20 txt_mudit_b11_1529.jpg
# 21 txt_mudit_b11_1534.jpg
# 22 txt_mudit_b11_1535.jpg
# 23 txt_mudit_b11_1536.jpg
# 24 txt_mudit_b11_1539.jpg
# 25 txt_mudit_b11_439.jpg
# 26 txt_mudit_b11_480.jpg
# 27 txt_mudit_b11_746.jpg
# 28 txt_mudit_b11_961.jpg
# 29 txt_mudit_b8_1_513.jpg
# 30 txt_mudit_b8_1_545.jpg
# 31 txt_mudit_b8_1_546.jpg
# 32 txt_mudit_b8_1_554.jpg
# 33 txt_mudit_b8_1_555.jpg
# 34 txt_mudit_b8_1_571.jpg
# 35 txt_mudit_b8_1_573.jpg
# 36 txt_mudit_b8_1_574.jpg
# 37 txt_mudit_b8_1_740.jpg
# 38 txt_mudit_b8_1_741.jpg
# 39 txt_mudit_b8_1_742.jpg
# 40 txt_mudit_b8_1_806.jpg
# 41 txt_mudit_b8_1_807.jpg
# 42 txt_mudit_b8_1_808.jpg
# 43 txt_mudit_b8_1_854.jpg
# 44 txt_mudit_b8_1_855.jpg
# 45 txt_mudit_b8_2_213.jpg

# %% [markdown]
# # Making a list(name = data) in which we append a list contains all 6 values( ["Regn number","Chassis number","Name","Engine number","Registration date","Mfg. date"] ) for each image so data list becomes a 2D list later we convert it to DataFrame using pandas

# %%
data=[]
j=0
for pic in filelist1:
    
    img=Image.open('RC\\images\\'+pic)                               # 'RC/'+pic is the directory of images taken one at a time
    en=ImageEnhance.Brightness(img)                         # imagenhance is used to manupulate image data in a better way
    img=en.enhance(1.2)
    en=ImageEnhance.Color(img)
    img=en.enhance(0.0)
    text=pytesseract.image_to_string(img)
    new_str=text.split()                                   # spliting text on the basis of space
    aa=[None]*6                                            #initializing list which hold all 6 values needed from a image
    data.append(aa)
    two=0
    for i in range(len(new_str)-6):
        
     #======  Fetching License plate number or Regn number   ===============================================================
        if new_str[i]=='REGN':
            if len(new_str[i+4])<9:
                    a=new_str[i+4]+new_str[i+5]
                    data[j][0]=a
            else:
                data[j][0]=new_str[i+4]
        else:
            if new_str[i]=='REGN.':
                if len(new_str[i+3])<9:
                    a=new_str[i+3]+new_str[i+4]
                    data[j][0]=a
                else:
                    data[j][0]=new_str[i+3]
        if new_str[i]=="Registration":
            if new_str[i+1]=="No.":
                if len(new_str[i+2])<9:
                    a=new_str[i+2]+new_str[i+3]
                    data[j][0]=a
                else:
                    data[j][0]=new_str[i+2]
                
        if 'HR' in new_str[i]:
            data[j][0]==new_str[i]
        
            
    #========== Fetching VIN number or Chassis number (typically 17 digit long)  ==========================================
        if new_str[i]=='CH.' or new_str[i]=='CH' :    
            data[j][1]=new_str[i+3]
            
        if new_str[i]=="Chassis" or new_str[i]=="Chasis":
            if new_str[i+1]=="No.":
                data[j][1]=new_str[i+2]
        
        
    # =========== Fetching Name  ==========================================================================================
        if new_str[i]=='NAME' or new_str[i]=='Name' or new_str[i]=='name':
            if '_' or '-' in new_str[i+1]:
                if new_str[i+2]==':' or new_str[i+1]==':.':
                    if new_str[i+3]=='MR' or new_str[i+3]=='mr' or new_str[i+3]=='Mr' or new_str[i+3]=='MR.' or new_str[i+3]=='mr.' or new_str[i+3]=='Mr.':
                        name=new_str[i+4]
                    else:
                        name=new_str[i+3]
                else:
                    if new_str[i+2]=='MR' or new_str[i+2]=='mr' or new_str[i+2]=='Mr' or new_str[i+2]=='MR.' or new_str[i+2]=='mr.' or new_str[i+2]=='Mr.':
                        name=new_str[i+3]
                    else:
                        name=new_str[i+2]
                    
            elif new_str[i+1]==':' or new_str[i+1]==':.':
                    if new_str[i+2]=='MR' or new_str[i+2]=='mr' or new_str[i+2]=='Mr' or new_str[i+2]=='MR.' or new_str[i+2]=='mr.' or new_str[i+2]=='Mr.':
                        name=new_str[i+3]
                    else:
                        name=new_str[i+2]
            elif new_str[i+1]=='MR' or new_str[i+1]=='mr' or new_str[i+1]=='Mr' or new_str[i+1]=='MR.' or new_str[i+1]=='mr.' or new_str[i+1]=='Mr.' :
                name=new_str[i+2]
            
            elif new_str[i-1]=="Owner's":
                name=new_str[i+1]
            elif "&" in new_str[i+1]:
                name=new_str[i+4] #i+4
            else:
                name=new_str[i+1]
            if two==0:
                data[j][2]=name
                two=1
                
                
    #=========== Fetching Engine number  ====================================================================================
        if new_str[i]=='ENO':
            if new_str[i+1]=='-' or new_str[i+1]=='_':
                data[j][3]=new_str[i+3]
            else:
                if new_str[i+2][-1]=='-':
                    a=str(new_str[i+2])+str(new_str[i+3])
                    data[j][3]=a
                else:
                    data[j][3]=new_str[i+2]
        if new_str[i]=="Engine":
            if len(new_str[i+2])<11:
                a=new_str[i+2]+new_str[i+3]
                data[j][3]=a
            else:
                data[j][3]=new_str[i+2]
                


    # ======== Fetching Registration date  ==============================================================================
        if new_str[i]=="REG." or new_str[i]=="REGN":
            if "DT" in new_str[i+1]:
                if new_str[i+2]==":":
                    reg_date=new_str[i+3]
                else:
                    reg_date=new_str[i+2]
                length=len(reg_date)
                reg_date=reg_date[:length-8]+" / "+reg_date[length-7:length-5]+" / "+reg_date[length-4:]        
            
                data[j][4]=reg_date
        
        
        
    # =============== Fetching Mfg. date  ================================================================================
        if new_str[i]=="Year":
            if new_str[i+1]=="of":
                if "Manu" in new_str[i+2]:
                    manufacture_date=new_str[i+3]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+" / "+manufacture_date[length-4:]
            data[j][5]=manufacture_date
            
        if new_str[i]=="Yr":
            if new_str[i+1]=="of":
                manufacture_date=new_str[i+2]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+" / "+manufacture_date[length-4:]
            data[j][5]=manufacture_date
        
        
        
        if new_str[i]=="Month":
            if new_str[i+3]=="of":
                if new_str[i+4]=="Mfg." or new_str[i+4]=="Mfg" or new_str[i+4]=="Mig." or new_str[i+4]=="Mig":
                    manufacture_date=new_str[i+5]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+"/"+manufacture_date[length-4:]
            data[j][5]=manufacture_date   
        
        if "MFG" in new_str[i]:
            if new_str[i+1]==":":
                manufacture_date=new_str[i+2]
            elif "DT" in new_str[i+1]:
                if new_str[i+2]==":":
                    manufacture_date=new_str[i+3]
                else:
                    manufacture_date=new_str[i+2]
            else:
                manufacture_date=new_str[i+1]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+"/"+manufacture_date[length-4:]
            data[j][5]=manufacture_date
        
        
    j+=1

# %% [markdown]
# # Making DataFrame from 2d list data

# %%
       
df=pd.DataFrame(data)
df.columns=["Regn number","Chassis number","Name","Engine number","Registration date","Mfg. date"]
df
# Out:
#      Regn number       Chassis number      Name       Engine number  \
# 0           None                 None      None                None
# 1     DL9CAC6215                 None     smsim                None
# 2   DL2CAT9109""    Masetoetsooztesss    cELERI             rserose
# 3      HROGP5988    MASEYD81500765439     SINGH                None
# 4       HROS8814                 None       «-~                None
# 5      HRASD0002    MASFJEB1$00404062      NATH       D13A22350Fue!
# 6     HROGAH1768    MASELMG1800384208    HARISH        K14BN7124809
# 7           None                 None     KUMAR                None
# 8     HROGAERZA3    MA3EJKD1$00683213     VINAY        K12MM1830003
# 9     HROGAK2102     MAFHEB1S00B§2684  JITENDER         D13A2099227
# 10    DL2CAUTII7    MASFLEB1S00309631      None                None
# 11    DL2CAS1294               COLOUR      ANIK        K12MN1262597
# 12    DL3CBU4111               COLOUR   SAURABH         DisA1e33010
# 13    DL13CA8614    MA3FHEB1S00593004    RAKESH        D13A-2307188
# 14    DL9CAC1454    MASEADE1500237206        OF                None
# 15          NO_:     MASEHKD1S0097129    SACHIN             1774707
# 16    DL9CAE2930    masrhestsoossrsos     karan                None
# 17    DL8CAH3172    MASETDE1S00159552   CHANDRA                None
# 18     DLSCJ7852    MASFJEB1S00828720    MEGHNA         DisA23e8220
# 19     DL5CJ5387                 None      None                None
# 20     DL8CU7889   MA3EUA6G1SO0170565     MAMTA        FBDN49598005
# 21     DLeCN3195    MASEWDE1SO0637165      None        K10BN4590508
# 22     DLSCJ4987                 None   MANJULA        K10BN7228183
# 23     DL8CP6677                  ENO      None                None
# 24          None                 None      None                None
# 25          None           MAGEFJC1S0     MANOJ                None
# 26         EcmJ"                 None      None                None
# 27          None                   Ma      None                None
# 28     DLSCJ6088    MASFHEB1S00520199   RAJNISH         D13A2235055
# 29    DL2CAMO993        MALBBS1BLAM21     KAMAL       G4LAAM4SSO$SS
# 30          None    MA3EED81800628175      ASHW        F10DN4452456
# 31          None                 None   Vehicle                None
# 32   HRlO‘P'084O                   :-   Address      _-G4EBIM246677
# 33          None                 None    MOTORS                None
# 34    DL3CAX6515     G6O7446KRZWO0622     VIKAS                  |_
# 35    DL3CAX6515     G6O7146KRZWO0622     VIKAS  47SIDTH4KRZPB8AM!9
# 36          None                 None      None                None
# 37    DL2CAF6866                 None      None                None
# 38    DL2CAF6866                   NO     smwiD                None
# 39    DL3CAD3216                 None   MAHABIR                None
# 40          None                 None      None                None
# 41          None  MALCM41VROMO79263*L   Address        D4FA9US17848
# 42          None                 None    MOTORS                None
# 43          None                 None      None                None
# 44          None                 None        _.                None
# 45          None                 None      None                None
#
#    Registration date       Mfg. date
# 0               None            None
# 1               None            None
# 2               None            None
# 3               None        9 / 2006
# 4               None      9 / / 2006
# 5               None        9 / 2013
# 6               None        4 / 2016
# 7               None        4 //2016
# 8               None        1 / 2016
# 9               None        9 / 2018
# 10              None            None
# 11              None            None
# 12     o / o8 / 2012             /CD
# 13    11 / 02 / 2014          0/2014
# 14     1 / 08 / 2011        ALT/ALTO
# 15    07 / 05 / 2016            None
# 16              None            None
# 17              None          1/2014
# 18    17 / 08 / 2014         04/2014
# 19              None            None
# 20    14 / 02 / 2013         12/2012
# 21     3 / 71 / 2013             /CD
# 22    12 / 04 / 2013         02/2013
# 23              None            None
# 24              None            None
# 25              None         08/2009
# 26              None            None
# 27              None            None
# 28      Ar /  / rete              /'
# 29              None             /CD
# 30              None  23/OI/‘ / 008'
# 31              None            None
# 32              None             / _
# 33              None            None
# 34    24 / 04 / 2009         10/2008
# 35    24 / 04 / 2009             /CD
# 36              None            None
# 37              None            None
# 38    03 / 04 / 2006            None
# 39              None            None
# 40              None            None
# 41              None    31/12 / 2009
# 42              None            None
# 43              None            None
# 44              None            None
# 45              None            None

# %% [markdown]
# # Prepare an excel  showing what was the text output for each image

# %%
df.to_csv('civic2.csv')

# %% [markdown]
# #  Note on the approach and methodology that used

# %% [markdown]
# In this project we use Python-tesseract. Python-tesseract is an optical character recognition (OCR) tool for python. That is, it will recognize and “read” the text embedded in images.
# We also used image enhencement technique for better text fetching such as brightness,color.Before starting we need to install pytesseract in anaconda command prompt (pip install pytesseract). Also we need to install tesseract.exe and assign its directory link is here(https://github.com/tesseract-ocr/tesseract/wiki/4.0-with-LSTM#400-alpha-for-windows).So after applying tesseract we will have string of text available on image.
# after that we will split text on the basis on space. so we will having a list of words.
# After that we make searching operations for "Regn number","Chassis number","Name","Engine number","Registration date","Mfg. date".
# after that make dataframe of this fetched data and save it in form of excel file.

# %% [markdown]
# In mostly images registration date is not given so i had used None at that place.Also if any data is not given or unable to fetched from the image i have Printed None
